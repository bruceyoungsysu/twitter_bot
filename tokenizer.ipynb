# %%
path = './trump_tweets.txt'
with open(path) as f:
    lines = f.readlines()

# %%
import nltk
from nltk.tokenize import word_tokenize
vocab = []
for line in lines:
    tokens = word_tokenize(line)
    vocab += tokens

# %%
vocab_set = set(vocab)

# %%
vocabs = [v for v in vocab_set if vocab.count(v)>100]

# %%
vocabs
# Out:
# ['know',
#  'friend',
#  'into',
#  'told',
#  'New',
#  'place',
#  'way',
#  'night',
#  'stop',
#  'working',
#  'while',
#  'if',
#  'American',
#  'Let',
#  'world',
#  'morning',
#  'Democrats',
#  'polls',
#  'FoxNews',
#  'News',
#  "n't",
#  'do',
#  'honor',
#  'let',
#  "'re",
#  'were',
#  'Iran',
#  'never',
#  'done',
#  'discussing',
#  'U.S.',
#  'ready',
#  '1',
#  'spending',
#  'but',
#  "'ve",
#  'give',
#  'one',
#  'still',
#  'Just',
#  'ago',
#  'interviewed',
#  'be',
#  'year',
#  'very',
#  'on',
#  'words',
#  'story',
#  'those',
#  'border',
#  'run',
#  'ApprenticeNBC',
#  'after',
#  'does',
#  'How',
#  'high',
#  'amazing',
#  'Join',
#  'life',
#  'vote',
#  'bring',
#  'See',
#  'good',
#  'over',
#  'end',
#  'job',
#  'hard',
#  'media',
#  'military',
#  'are',
#  'winning',
#  'Thanks',
#  'Good',
#  'failing',
#  'its',
#  'live',
#  'Star',
#  'GREAT',
#  'great',
#  'Golf',
#  'trade',
#  'interview',
#  'Think',
#  'of',
#  'I',
# ...

# %%
len(vocabs)
# Out:
# 497

# %%
len(vocab)
# Out:
# 434347

# %%
with open('./vocab_tokenized_all.txt','w') as f:
    for item in vocab:
        f.write("%s\n" %item)
    f.close()
